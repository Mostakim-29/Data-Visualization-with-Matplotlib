# %% [markdown]
# **Introduction to data visualization with Matplotlib**

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
fig, ax = plt.subplots()
plt.show()

# %%
seattle_weather = pd.read_csv('data/seattle_weather.csv')
austin_weather = pd.read_csv('data/austin_weather.csv')

# %%
df1 = seattle_weather.groupby('DATE').agg(
    MLY_TAVG_NORMAL = ('MLY-TAVG-NORMAL', 'mean')
)
df1['MONTH'] = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
df1
# Out:
#       MLY_TAVG_NORMAL MONTH
# DATE
# 1           40.980000   Jan
# 2           42.320000   Feb
# 3           45.693333   Mar
# 4           49.646667   Apr
# 5           55.186667   May
# 6           60.093333   Jun
# 7           64.733333   Jul
# 8           65.106667   Aug
# 9           60.040000   Sep
# 10          51.800000   Oct
# 11          44.540000   Nov
# 12          39.473333   Dec

# %%
df2 = austin_weather.groupby('DATE').agg(
    MLY_TAVG_NORMAL = ('MLY-TAVG-NORMAL', 'mean')
)
df2['MONTH'] = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
df2
# Out:
#       MLY_TAVG_NORMAL MONTH
# DATE
# 1                49.2   Jan
# 2                52.1   Feb
# 3                59.2   Mar
# 4                67.3   Apr
# 5                75.2   May
# 6                81.0   Jun
# 7                83.4   Jul
# 8                83.7   Aug
# 9                77.8   Sep
# 10               69.0   Oct
# 11               58.4   Nov
# 12               50.4   Dec

# %%
fig, ax = plt.subplots()
ax.plot(df1['MONTH'], df1['MLY_TAVG_NORMAL'])
ax.plot(df2['MONTH'], df2['MLY_TAVG_NORMAL'])
plt.show()

# %%
df1 = seattle_weather.groupby('DATE').agg(
    MLY_PRCP_NORMAL = ('MLY-PRCP-NORMAL', 'mean')
)
df1['MONTH'] = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
df2 = austin_weather.groupby('DATE').agg(
    MLY_PRCP_NORMAL = ('MLY-PRCP-NORMAL', 'mean')
)
df2['MONTH'] = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# %%
fig, ax = plt.subplots()
ax.plot(df1['MONTH'], df1['MLY_PRCP_NORMAL'])
ax.plot(df2['MONTH'], df2['MLY_PRCP_NORMAL'])
plt.show()

# %% [markdown]
# **Customizing your plots**

# %%
fig, ax = plt.subplots()
ax.plot(df1['MONTH'], df1['MLY_PRCP_NORMAL'], color = 'b', marker = 'o', linestyle = '--')
ax.plot(df2['MONTH'], df2['MLY_PRCP_NORMAL'], color = 'r', marker = 'v', linestyle = '--')
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(df1['MONTH'], df1['MLY_PRCP_NORMAL'], color = 'b', marker = 'o', linestyle = '--')
ax.plot(df2['MONTH'], df2['MLY_PRCP_NORMAL'], color = 'r', marker = 'v', linestyle = '--')
ax.set_xlabel('Time (months)')
ax.set_ylabel('Precipitation (inches)')
ax.set_title('Weather patterns in Austin and Seattle')
plt.show()

# %% [markdown]
# **Small multiples**

# %%
df1 = seattle_weather.groupby('DATE').agg(
    MLY_TAVG_NORMAL = ('MLY-TAVG-NORMAL', 'mean'),
    MLY_PRCP_NORMAL = ('MLY-PRCP-NORMAL', 'mean')
)
df1['MONTH'] = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
df2 = austin_weather.groupby('DATE').agg(
    MLY_TAVG_NORMAL = ('MLY-TAVG-NORMAL', 'mean'),
    MLY_PRCP_NORMAL = ('MLY-PRCP-NORMAL', 'mean')
)
df2['MONTH'] = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# %%
fig, ax = plt.subplots(2, 2)

# %%
fig, ax = plt.subplots(2, 2)
ax[0,0].plot(df1['MONTH'], df1['MLY_PRCP_NORMAL'])
ax[0,1].plot(df1['MONTH'], df1['MLY_TAVG_NORMAL'])
ax[1,0].plot(df2['MONTH'], df2['MLY_PRCP_NORMAL'])
ax[1,1].plot(df2['MONTH'], df2['MLY_TAVG_NORMAL'])
plt.show()

# %%
df1 = seattle_weather.groupby('DATE').agg(
    MLY_PRCP_25PCTL = ('MLY-PRCP-25PCTL', 'mean'),
    MLY_PRCP_NORMAL = ('MLY-PRCP-NORMAL', 'mean'),
    MLY_PRCP_75PCTL = ('MLY-PRCP-75PCTL', 'mean')
)
df1['MONTH'] = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
df2 = austin_weather.groupby('DATE').agg(
    MLY_PRCP_25PCTL = ('MLY-PRCP-25PCTL', 'mean'),
    MLY_PRCP_NORMAL = ('MLY-PRCP-NORMAL', 'mean'),
    MLY_PRCP_75PCTL = ('MLY-PRCP-75PCTL', 'mean')
)
df2['MONTH'] = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# %%
fig, ax = plt.subplots(2, 1, sharey=True)

ax[0].plot(df1['MONTH'], df1['MLY_PRCP_NORMAL'], color='b')
ax[0].plot(df1['MONTH'], df1['MLY_PRCP_25PCTL'], color='b', linestyle='--')
ax[0].plot(df1['MONTH'], df1['MLY_PRCP_75PCTL'], color='b', linestyle='--')

ax[1].plot(df2['MONTH'], df2['MLY_PRCP_NORMAL'], color='r')
ax[1].plot(df2['MONTH'], df2['MLY_PRCP_25PCTL'], color='r', linestyle='--')
ax[1].plot(df2['MONTH'], df2['MLY_PRCP_75PCTL'], color='r', linestyle='--') 
plt.show()

# %% [markdown]
# **Plotting time-series data**

# %% [markdown]
# **Read data with a time index**

# %%
climate_change = pd.read_csv('data/climate_change.csv', parse_dates=["date"], index_col="date")
climate_change.head()
# Out:
#                co2  relative_temp
# date
# 1958-03-06  315.71           0.10
# 1958-04-06  317.45           0.01
# 1958-05-06  317.50           0.08
# 1958-06-06     NaN          -0.05
# 1958-07-06  315.86           0.06

# %% [markdown]
# **Plot time-series data**

# %%
fig, ax = plt.subplots()
ax.plot(climate_change.index, climate_change['relative_temp'])
ax.set_xlabel('Time')
ax.set_ylabel('Relative temperature (Celsius)')
plt.show()

# %% [markdown]
# **Using a time index to zoom in**

# %%
seventies = climate_change["1970-01-01":"1979-12-31"]
seventies.head()
# Out:
#                co2  relative_temp
# date
# 1970-01-06  325.03           0.09
# 1970-02-06  325.99           0.22
# 1970-03-06  326.87           0.08
# 1970-04-06  328.13           0.09
# 1970-05-06  328.07          -0.05

# %%
fig, ax = plt.subplots()
ax.plot(seventies.index, seventies['co2'])
plt.show()

# %% [markdown]
# **Plotting time-series with different variables**

# %% [markdown]
# ***Plotting two variables***

# %%
fig, ax = plt.subplots()
ax.plot(climate_change.index, climate_change['co2'], color='b')
ax2 = ax.twinx()
ax2.plot(climate_change.index, climate_change['relative_temp'], color='r')
plt.show()

# %% [markdown]
# **Defining a function that plots time-series data**

# %%
def plot_timeseries(axes, x, y, color, xlabel, ylabel):
    axes.plot(x, y, color=color)
    axes.set_xlabel(xlabel)
    axes.set_ylabel(ylabel, color=color)
    axes.tick_params('y', colors=color)

# %%
fig, ax = plt.subplots()
plot_timeseries(
    axes=ax,
    x=climate_change.index,
    y=climate_change['co2'],
    color="blue",
    xlabel="Time (years)",
    ylabel="CO2 levels"
)
ax2=ax.twinx()
plot_timeseries(
    axes=ax2,
    x=climate_change.index,
    y=climate_change['relative_temp'],
    color="red",
    xlabel="Time (years)",
    ylabel="Relative temperature (Celsius)"
)
plt.show()

# %% [markdown]
# **Annotating time-series data**

# %%
fig, ax = plt.subplots()
ax.plot(climate_change.index, climate_change['relative_temp'])
ax.annotate('>1 degree', xy=(pd.Timestamp('2015-10-06'), 1))
plt.show()

# %%
fig, ax = plt.subplots()
plot_timeseries(
    axes=ax,
    x=climate_change.index,
    y=climate_change['co2'],
    color="blue",
    xlabel="Time (years)",
    ylabel="CO2 levels"
)
ax2=ax.twinx()
plot_timeseries(
    axes=ax2,
    x=climate_change.index,
    y=climate_change['relative_temp'],
    color="red",
    xlabel="Time (years)",
    ylabel="Relative temperature (Celsius)"
)
ax2.annotate('>1 degree', 
             xy=(pd.Timestamp('2015-10-06'), 1),
             xytext=(pd.Timestamp('1990-10-06'), 1.25),
             arrowprops={'arrowstyle':'->', 'color':'purple'})

plt.show()

# %% [markdown]
# **Quantitative comparisons: bar-charts**

# %%
medals = pd.read_csv('data/medals_by_country_2016.csv', index_col=0)
medals.head()
# Out:
#                Bronze  Gold  Silver
# United States      67   137      52
# Germany            67    47      43
# Great Britain      26    64      55
# Russia             35    50      28
# China              35    44      30

# %%
fig, ax = plt.subplots()
ax.bar(medals.index, medals['Gold'])
ax.set_xticklabels(medals.index, rotation=90)
ax.set_ylabel('Number of medals')
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10668\1364880069.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(medals.index, rotation=90)

# %% [markdown]
# **Stacked bar chart**

# %%
fig, ax = plt.subplots()
ax.bar(medals.index, medals['Gold'], label='Gold')
ax.bar(medals.index, medals['Silver'], bottom=medals['Gold'], label='Silver')
ax.bar(medals.index, medals['Bronze'], bottom=medals['Gold']+medals['Silver'], label='Bronze')
ax.set_xticklabels(medals.index, rotation=90)
ax.set_ylabel('Number of medals')
ax.legend()
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10668\1968749726.py:5: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(medals.index, rotation=90)

# %% [markdown]
# **Quantitative comparisons: histograms**

# %%
summer2016 = pd.read_csv('data/summer2016.csv')
mens_rowing = summer2016[summer2016['Sport'] == 'Rowing']
mens_gymnastics = summer2016[summer2016['Sport'] == 'Gymnastics']

# %%
fig, ax = plt.subplots()
ax.hist(mens_rowing['Weight'])
ax.hist(mens_gymnastics['Weight'])
ax.set_xlabel('Weight (kg)')
ax.set_ylabel('# of observations')
plt.show()

# %%
fig, ax = plt.subplots()
ax.hist(mens_rowing['Weight'], bins=5, histtype='step', label='Rowing')
ax.hist(mens_gymnastics['Weight'], bins=5, histtype='step', label='Gymnastics')
ax.set_xlabel('Weight (kg)')
ax.set_ylabel('# of observations')
ax.legend()
plt.show()

# %% [markdown]
# **Statistical plotting**

# %% [markdown]
# **Adding error-bars to a bar chart**

# %%
fig, ax = plt.subplots()
ax.bar("Rowing", mens_rowing['Height'].mean(), yerr=mens_rowing['Height'].std())
ax.bar("Gymnastics", mens_gymnastics['Height'].mean(), yerr=mens_gymnastics['Height'].std())
ax.set_ylabel('Height (cm)')
plt.show()

# %% [markdown]
# **Adding error-bars to a bar chart**

# %%
df1 = seattle_weather.groupby('DATE').agg(
    MLY_TAVG_NORMAL = ('MLY-TAVG-NORMAL', 'mean'),
    MLY_TAVG_STDDEV = ('MLY-TAVG-STDDEV', 'mean')
)
df1['MONTH'] = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
df2 = austin_weather.groupby('DATE').agg(
    MLY_TAVG_NORMAL = ('MLY-TAVG-NORMAL', 'mean'),
    MLY_TAVG_STDDEV = ('MLY-TAVG-STDDEV', 'mean')
)
df2['MONTH'] = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# %%
fig, ax = plt.subplots()
ax.errorbar(
    df1['MONTH'], 
    df1['MLY_TAVG_NORMAL'], 
    yerr=df1['MLY_TAVG_STDDEV']
)
ax.errorbar(
    df2['MONTH'], 
    df2['MLY_TAVG_NORMAL'], 
    yerr=df2['MLY_TAVG_STDDEV']
)
ax.set_ylabel('Temperature (Fahrenheit)')
plt.show()

# %% [markdown]
# **Creating boxplot**

# %%
fig, ax = plt.subplots()
ax.boxplot([mens_rowing['Height'], mens_gymnastics['Height']])
ax.set_xticklabels(["Rowing", "Gymnastics"])
ax.set_ylabel('Height (cm)')
plt.show()

# %% [markdown]
# **Quantitative comparisons: scatter plots**

# %% [markdown]
# ***Simple scatter plot***

# %%
fig, ax = plt.subplots()
ax.scatter(
    climate_change['co2'],
    climate_change['relative_temp']
)
ax.set_xlabel("CO2 (ppm)")
ax.set_ylabel("Relative temperature (C)" )
plt.show()

# %%
eighties = climate_change["1980-01-01":"1989-12-31"]
nineties = climate_change["1990-01-01":"1999-12-31"]
fig, ax = plt.subplots()
ax.scatter(
    x=eighties['co2'],
    y=eighties['relative_temp'],
    color='b',
    label='eighties'
)
ax.scatter(
    x=nineties['co2'],
    y=nineties['relative_temp'],
    color='r',
    label='nineties'
)
ax.set_xlabel("CO2 (ppm)")
ax.set_ylabel("Relative temperature (C)")
ax.legend()
plt.show()

# %% [markdown]
# ***Encoding time by color***

# %%
fig, ax = plt.subplots()
ax.scatter(
    climate_change['co2'], 
    climate_change['relative_temp'],
    c=climate_change.index
)
ax.set_xlabel("CO2 (ppm)")
ax.set_ylabel("Relative temperature (C)")
plt.show()

# %% [markdown]
# **Preparing your figures to share with others**

# %% [markdown]
# **Switching between styles**

# %%
plt.style.use('ggplot')
fig, ax = plt.subplots()
ax.plot(df1['MONTH'], df1['MLY_TAVG_NORMAL'])
plt.show()

# %%
plt.style.use('Solarize_Light2')
fig, ax = plt.subplots()
ax.plot(df1['MONTH'], df1['MLY_TAVG_NORMAL'])
plt.show()

# %% [markdown]
# **Saving your visualizations**

# %% [markdown]
# **Saving a file several times**

# %%
plt.style.use('default')
fig, ax = plt.subplots()
ax.bar(medals.index, medals['Gold'])
ax.set_xticklabels(medals.index, rotation=90)
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10668\240458387.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(medals.index, rotation=90)

# %%
fig.savefig('medals_by_country.png')

# %%
fig.savefig('medals_by_country_300dpi.png', dpi=300)

# %%
fig.set_size_inches([3, 5])
fig.savefig('medals_by_country_3x5.png')

# %%
fig.set_size_inches([5, 3])
fig.savefig('medals_by_country_5x3.png')

# %%
fig.savefig('medals_by_country.jpg')

# %% [markdown]
# **Automating figures from data**

# %%
sports_column = summer2016['Sport']
sports = summer2016['Sport'].unique()
print(sports)
# Out:
# ['Rowing' 'Taekwondo' 'Handball' 'Wrestling' 'Gymnastics' 'Swimming'
#  'Basketball' 'Boxing' 'Volleyball' 'Athletics' 'Rugby Sevens' 'Judo'
#  'Rhythmic Gymnastics' 'Weightlifting' 'Equestrianism' 'Badminton'
#  'Water Polo' 'Football' 'Fencing' 'Shooting' 'Sailing' 'Beach Volleyball'
#  'Canoeing' 'Hockey' 'Cycling' 'Tennis' 'Diving' 'Table Tennis'
#  'Triathlon' 'Archery' 'Synchronized Swimming' 'Modern Pentathlon'
#  'Trampolining' 'Golf']

# %%
fig, ax = plt.subplots()
for sport in sports:
    sport_df = summer2016[summer2016['Sport'] == sport]
    ax.bar(sport, sport_df['Weight'].mean(), yerr=sport_df['Weight'].std())
ax.set_ylabel('Weight')
ax.set_xticklabels(sports, rotation=90)
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10668\2419168561.py:6: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(sports, rotation=90)

# %%
fig.savefig('sports_weights.png')

# %% [markdown]
# *Another method*

# %%
df = summer2016.groupby('Sport').agg(
    Weight=('Weight', 'mean'),
    Weight_std=('Weight', 'std')
)

# %%
fig, ax = plt.subplots()
ax.bar(
    x=df.index,
    height=df['Weight'],
    yerr=df['Weight_std']
)
ax.set_ylabel('Weight')
ax.set_xticklabels(sports, rotation=90)
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10668\1738276352.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(sports, rotation=90)
